# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
import requests

url = 'https://www.datos.gov.co/api/views/gt2j-8ykr/rows.csv?accessType=DOWNLOAD&bom=true&format=true'

myfile = requests.get(url)

open('/Users/andresmauriciotrianareina/Documents/Cursos Udemy:SAS:FutureLearn/Data_science/My_excercise/0_prueba/Análisis Covid/Versión web 2/Colombia/Casos_positivos_de_COVID-19_en_Colombia.csv', 'wb').write(myfile.content)
# Out:
# 81053659

# %%
df = pd.read_csv('Casos_positivos_de_COVID-19_en_Colombia.csv')
df.head()
# Out:
# /Users/andresmauriciotrianareina/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning:
#
# Columns (10,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#    ID de caso    Fecha de notificación  Código DIVIPOLA  Ciudad de ubicación  \
# 0           1  2020-03-02T00:00:00.000            11001          Bogotá D.C.
# 1           2  2020-03-06T00:00:00.000            76111  Guadalajara de Buga
# 2           3  2020-03-07T00:00:00.000             5001             Medellín
# 3           4  2020-03-09T00:00:00.000             5001             Medellín
# 4           5  2020-03-09T00:00:00.000             5001             Medellín
#
#   Departamento o Distrito     atención  Edad Sexo         Tipo Estado  ...  \
# 0              Bogotá D.C.  Recuperado    19    F    Importado   Leve  ...
# 1          Valle del Cauca  Recuperado    34    M    Importado   Leve  ...
# ...
